# %%
import person_identification_model
import feature_pipeline

# %%
dataset_path = "dataset"

X, y = feature_pipeline.build_dataset(dataset_path)

print(X.shape)
print(y)
# Out:
# Processing OFF...
# Processing ON...
# (0,)
# []

# %%
print(X)
print(y)
# Out:
# []
# []
